# %% [markdown]
# THEORITICAL QUESTIONS:

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#     - Functions- Defined using def, can be used independently.
#       Method- A function associated with an object.

# %%
def add(a, b ):   #function
  return a + b

lst = [1, 2, 3]   #method
lst.append(4)

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#     - Parameter is a variable in a function whereas, Argument is an actual value passed during the call.

# %%
def greet(name = "palak")  #name = parameter & "palak" = argument

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#     -

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
#     - Return statement is used to send the value from a function back to the caller.

# %%
def add(a, b):
  return a + b
result = add(2, 3)
print(result)
# Out:
# 5

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#     - An iteraterable is any python object/subsequential data structure that is capable of retrning its member one at a time. [list, tuples].
#
#         Iterator is an object representing a stream of data. It return the data next.

# %%
nums = [1,2,3,4]
a = iter(nums)
print(next(a))

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#     - Generators are the functions that yield one value at a time. defined as yield.

# %%
def gen():
  for i in range (3):
    yield i
for x in gen():
  print(x)
# Out:
# 0
# 1
# 2

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#     - Advantages of generators :
#     1. Faster for larger data sets
#     2. Maintain state automatically

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#     - An anonyous function that don't need def keyword or return statement and it still excutes the code.

# %%
square = lambda x: x**2
print(square(5))

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python.
#     - It executes a specified functions for each of an item in an iterable.

# %%
def square(x):
  return x**2
list(map(square, [1,2]))
# Out:
# [1, 4]

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#     - Map - Applies a function to all elements,
#       Filter - Filters elements from an iterable based on some condition,
#       Reduce - Combines elements into one value

# %%
map(lambda x: x*2,[1,2,3])
filter(lambda x: x>2, [1,2,3])
reduce(lambda x: x+y, [1,2,3])

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using reduce function on this given
# list:[47,11,42,13]
# ![reduce mechanism.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# PRACTICAL QUESTIONS -

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_even(numbers):
  return sum [i for i in numbers if i % 2 == 0]

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
  return s[::-1]

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_numbers(numbers):
  return [i**2 for i in numbers]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def power_of_two(limit):
  for i in range(limit+1):
    yield 2**1

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file(file):
  with open(file, 'r') as f:
    for line in f:
      yield line.strip()

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
list = [(1,2), (2,3,3,4)]
sorted(list, key= lambda x: x[1])

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
temperature_c = [37, 100]
temperature_f = list(map(lambda x: (9/5)*x + 32, temperature_c))

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
string = 'hello'
vowels = 'aeiou'
result = ''.join(filter(lambda char: char not in vowels, string))
print(result)
# Out:
#   File "/tmp/ipython-input-1321913676.py", line 2
#     result = (filter(lambda, not in 'aeiou', string))
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
#
#
#
#
#
#
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.
